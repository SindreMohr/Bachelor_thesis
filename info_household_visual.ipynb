# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt

#enable IPython to display matplolib graphs
# %matplotlib inline

# %%
hhi_df = pd.read_csv("./data/informations_households.csv")

# %%
hhi_df.head(2000)

# %%
hhi_df.shape
# Out:
# (5566, 5)

# %%
hhi_df.columns
# Out:
# Index(['LCLid', 'stdorToU', 'Acorn', 'Acorn_grouped', 'file'], dtype='object')

# %%
hhi_df["Acorn_grouped"]
# Out:
# 0         ACORN-
# 1         ACORN-
# 2       Affluent
# 3       Affluent
# 4       Affluent
#           ...
# 5561     ACORN-U
# 5562     ACORN-U
# 5563     ACORN-U
# 5564     ACORN-U
# 5565     ACORN-U
# Name: Acorn_grouped, Length: 5566, dtype: object

# %%
hhi_df["Acorn_grouped"].value_counts().plot.bar(figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
hhi_df["Acorn_grouped"].value_counts().plot.pie(title="Household Affluency ", ylabel="", figsize=(15,10) , autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'Household Affluency '}>

# %%
aff_filt = hhi_df["Acorn_grouped"] == "Affluent"
comf_filt= hhi_df["Acorn_grouped"] == "Comfortable"
adversity_filt = hhi_df["Acorn_grouped"] == "Adversity"

# %%
hhi_df[adversity_filt].head()
# Out:
#           LCLid stdorToU    Acorn Acorn_grouped      file
# 3701  MAC002883      Std  ACORN-K     Adversity  block_74
# 3702  MAC002657      Std  ACORN-K     Adversity  block_74
# 3703  MAC001195      Std  ACORN-K     Adversity  block_74
# 3704  MAC000802      Std  ACORN-K     Adversity  block_74
# 3705  MAC002655      Std  ACORN-K     Adversity  block_74

# %%
hhi_df["Acorn"].value_counts().plot.bar(figsize=(15,10))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 285
# <AxesSubplot:>

# %%
hhi_df["Acorn"].value_counts().plot.pie(title="Household Acorn ", ylabel="", figsize=(15,10) , autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'Household Acorn '}>
