# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
from datetime import datetime


from data_read import load_data_into_dataframe

#enable IPython to display matplolib graphs
# %matplotlib inline

# %%
df = load_data_into_dataframe("daily")
df.head()
# Out:
#        LCLid         day  energy_median  energy_mean  energy_max  \
# 0  MAC002357  2012-04-27         0.1245     0.129083       0.288
# 1  MAC002357  2012-04-28         0.0850     0.128792       0.911
# 2  MAC002357  2012-04-29         0.0875     0.110396       0.504
# 3  MAC002357  2012-04-30         0.0795     0.111583       0.774
# 4  MAC002357  2012-05-01         0.0795     0.110292       0.607
#
#    energy_count  energy_std  energy_sum  energy_min
# 0            24    0.065268       3.098       0.034
# 1            48    0.147929       6.182       0.033
# 2            48    0.094689       5.299       0.034
# 3            48    0.119959       5.356       0.034
# 4            48    0.085291       5.294       0.034

# %%
df.columns
# Out:
# Index(['LCLid', 'day', 'energy_median', 'energy_mean', 'energy_max',
#        'energy_count', 'energy_std', 'energy_sum', 'energy_min'],
#       dtype='object')

# %%
df.shape
# Out:
# (3510433, 9)

# %%
#A heat map of correlation may give us a understanding of which variables are important
def plot_correlation_map(df):
    corr = df.corr()
    _ , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sbn.diverging_palette( 220 , 10 , as_cmap = True )
    _ = sbn.heatmap(corr, cmap = cmap, square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, annot = True, annot_kws = { 'fontsize' : 12 })

def plot_distribution( df , var , target , **kwargs ):
    row = kwargs.get( 'row' , None )
    col = kwargs.get( 'col' , None )
    facet = sbn.FacetGrid( df , hue=target , aspect=4 , row = row , col = col )
    facet.map( sbn.kdeplot , var , shade= True )
    facet.set( xlim=( 0 , df[ var ].max() ) )
    facet.add_legend()

# %% [markdown]
# sort out datetime

# %%
df["day"] = pd.to_datetime(df["day"])

# %%
df.loc[0,"day"].day_name()
# Out:
# 'Friday'

# %%
plot_correlation_map(df)

# %%
affluenthh_filt = df["LCLid"] == "MAC000002"

# %%
affluent_hh_data = df[affluenthh_filt]

# %%
affluent_hh_data.describe
# Out:
# <bound method NDFrame.describe of              LCLid        day  energy_median  energy_mean  energy_max  \
# 3140543  MAC000002 2012-10-12         0.1385     0.154304       0.886
# 3140544  MAC000002 2012-10-13         0.1800     0.230979       0.933
# 3140545  MAC000002 2012-10-14         0.1580     0.275479       1.085
# 3140546  MAC000002 2012-10-15         0.1310     0.213688       1.164
# 3140547  MAC000002 2012-10-16         0.1450     0.203521       0.991
# ...            ...        ...            ...          ...         ...
# 3141043  MAC000002 2014-02-24         0.1345     0.261000       0.891
# 3141044  MAC000002 2014-02-25         0.1925     0.246375       0.802
# 3141045  MAC000002 2014-02-26         0.1515     0.256833       1.028
# 3141046  MAC000002 2014-02-27         0.2180     0.427458       1.350
# 3141047  MAC000002 2014-02-28         1.3870     1.387000       1.387
#
#          energy_count  energy_std  energy_sum  energy_min
# ...

# %%
affluent_hh_data.plot(x="day", y="energy_mean", figsize=(20,5))

# %%
year_2013 = affluent_hh_data["day"].dt.year == 2013

# %%
affluent_hh_data.loc[3092716,"day"].year
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3092716
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
affluent_hh_data[year_2013].plot(x="day", y=["energy_mean","energy_max", "energy_min"],ylabel="kWh/hh", figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='day', ylabel='kWh/hh'>

# %% [markdown]
# MAC000002 Seems to be missing accurate measurements looking at the valleys of the plot, multiple 0 energy measures,
# though maybe this can be explained by other reasons, such as going on holiday or other edgecases where little energy is consumed

# %% [markdown]
# Now look at 2013 comfortable household, (households taken from info_household notebook)

# %%
comf_hh_filt = df["LCLid"] == "MAC001028"
comf_hh_data = df[comf_hh_filt]

# %%
comf_hh_data["day"].min()
# Out:
# Timestamp('2012-05-03 00:00:00')
# ERROR! Session/line number was not unique in database. History logging moved to new session 169

# %%
comf_hh_data["day"].max()
# Out:
# Timestamp('2013-11-23 00:00:00')

# %%
year_2013 = comf_hh_data["day"].dt.year == 2013

# %%
comf_hh_data.plot(x="day", y=["energy_mean"],ylabel="kWh/hh", figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='day', ylabel='kWh/hh'>

# %%
comf_hh_data[year_2013].plot(x="day", y=["energy_mean","energy_max", "energy_min"],ylabel="kWh/hh", figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='day', ylabel='kWh/hh'>

# %% [markdown]
# (should be comparing all households somehow for scientific conclusions)

# %% [markdown]
# Adversity household next

# %%
adv_hh_filt = df["LCLid"] == "MAC002657"
adv_hh_data = df[adv_hh_filt]
year_2013 = adv_hh_data["day"].dt.year == 2013

# %%
adv_hh_data["day"].min()
# Out:
# Timestamp('2012-05-04 00:00:00')

# %%
adv_hh_data["day"].max()
# Out:
# Timestamp('2014-02-28 00:00:00')

# %%
adv_hh_data[year_2013].plot(x="day", y=["energy_mean","energy_max", "energy_min"],ylabel="kWh/hh", figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='day', ylabel='kWh/hh'>
