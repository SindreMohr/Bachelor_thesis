# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()


# Deep learning packages
from keras.models import Sequential
from keras.layers import LSTM, Dense

#enable IPython to display matplolib graphs
# %matplotlib inline
# Out:
# 2022-04-05 09:24:21.448070: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-05 09:24:21.448092: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
from ML_classes.MLPModel import MLPModel

# %%
df = pd.read_csv('../data/ouput.csv')
df['tstp'] = [datetime.strptime(x, '%Y-%m-%d %H:%M:%S') for x in df['tstp']]
#df["tstp"] = pd.to_datetime(df["tstp"])
df["energy(kWh/hh)"] = pd.to_numeric(df["energy(kWh/hh)"], downcast="float", errors="coerce")

#max_value_energy = df["energy(kWh/hh)"].max()
#df['energy(kWh/hh)'] = df['energy(kWh/hh)'].apply(lambda x: x / max_value_energy)
# Sorting the values
#df.sort_values('tstp', inplace=True)

# %%
lclid_list = df['LCLid'].unique()
def find_household(identification):
    affluenthh_filt = df["LCLid"] == identification
    affluent_hh_data = df[affluenthh_filt]
    return affluent_hh_data

hh = find_household("MAC000153")

# %%
lclid_list = df['LCLid'].unique().tolist()
hh = pd.DataFrame()
for house in lclid_list:
    if house == "MAC000168":
        continue
    if house == "MAC000152":
        continue

    hd = find_household(house)
    hh = pd.concat([hh, hd])

# %%
hh.head
# Out:
# <bound method NDFrame.head of             LCLid                tstp  energy(kWh/hh)
# 39647   MAC000169 2011-11-24 13:30:00           0.811
# 39648   MAC000169 2011-11-24 14:00:00           0.321
# 39649   MAC000169 2011-11-24 14:30:00           0.362
# 39650   MAC000169 2011-11-24 15:00:00           0.257
# 39651   MAC000169 2011-11-24 15:30:00           0.457
# ...           ...                 ...             ...
# 396547  MAC000150 2014-02-27 22:00:00           0.631
# 396548  MAC000150 2014-02-27 22:30:00           0.178
# 396549  MAC000150 2014-02-27 23:00:00           0.108
# 396550  MAC000150 2014-02-27 23:30:00           0.078
# 396551  MAC000150 2014-02-28 00:00:00           0.113
#
# [317187 rows x 3 columns]>

# %%
hh.pop("LCLid")
#hh = hh.set_index("tstp")
#hh = hh.resample("H").sum()
#hh = hh.reset_index()

hh_max = hh['energy(kWh/hh)'].max()
hh['energy(kWh/hh)'] = hh['energy(kWh/hh)'].apply(lambda x: x / hh_max)

# %%
# Initiating the class
deep_learner = MLPModel(
data = hh,
Y_var = 'energy(kWh/hh)',
lag = 24*2,
layer_depths = [30],
layer_count= 1,
epochs = 20,
batch_size = 256,
train_test_split = 0.15
)

# %%
# Fitting the model

model = deep_learner.MLPModel()
# Out:
# Epoch 1/20
# 2022-04-05 09:24:27.822623: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-05 09:24:27.823133: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-05 09:24:27.823202: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-04-05 09:24:27.823265: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-04-05 09:24:27.823329: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-04-05 09:24:27.823378: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-04-05 09:24:27.823419: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-04-05 09:24:27.823459: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-04-05 09:24:27.823500: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-04-05 09:24:27.823507: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-04-05 09:24:27.823733: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1053/1053 [==============================] - 1s 920us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 2/20
# 1053/1053 [==============================] - 1s 850us/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 3/20
# 1053/1053 [==============================] - 1s 830us/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 4/20
# 1053/1053 [==============================] - 1s 930us/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 5/20
# 1053/1053 [==============================] - 1s 843us/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 6/20
# 1053/1053 [==============================] - 1s 943us/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 7/20
# 1053/1053 [==============================] - 1s 911us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 8/20
# 1053/1053 [==============================] - 1s 854us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 9/20
# 1053/1053 [==============================] - 1s 852us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 10/20
# 1053/1053 [==============================] - 1s 834us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 11/20
# 1053/1053 [==============================] - 1s 836us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 12/20
# 1053/1053 [==============================] - 1s 828us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 13/20
# 1053/1053 [==============================] - 1s 844us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 14/20
# 1053/1053 [==============================] - 1s 844us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 15/20
# 1053/1053 [==============================] - 1s 827us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 16/20
# 1053/1053 [==============================] - 1s 833us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 17/20
# 1053/1053 [==============================] - 1s 829us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 18/20
# 1053/1053 [==============================] - 1s 828us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 19/20
# 1053/1053 [==============================] - 1s 831us/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 20/20
# 1053/1053 [==============================] - 1s 839us/step - loss: 0.0014 - val_loss: 0.0014

# %%
deep_learner.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                1470
#
#  dense_1 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 1,501
# Trainable params: 1,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.ylim([0, 0.1])
    plt.xlabel('Epoch')
    plt.ylabel('Error [energy(kWh/hh)]')
    plt.legend()
    plt.grid(True)
plot_loss(deep_learner.history)

# %%
# Defining the lag that we used for training of the model 
lag_model = 48
# Getting the last period
ts = hh['energy(kWh/hh)'].tail(lag_model).values.tolist()
# Creating the X matrix for the model
X, _ = deep_learner.dc.create_X_Y(ts, lag=lag_model)
# Getting the forecast
yhat = model.predict(X)

# %%
yhat = deep_learner.predict()
# Constructing the forecast dataframe
fc = hh.tail(len(yhat)).copy()
fc.reset_index(inplace=True)
fc['forecast'] = yhat
# Ploting the forecasts
plt.figure(figsize=(12, 8))
for dtype in ['energy(kWh/hh)', 'forecast']:
  plt.plot(
    'tstp',
    dtype,
    data=fc,
    label=dtype,
    alpha=0.8
  )
plt.legend()
plt.grid()

# %%
#Forecasting n steps ahead
n_ahead = 168*2
yhat = deep_learner.predict_n_ahead(n_ahead)
yhat = [y[0][0] for y in yhat]

#Constructing the forecast dataframe
fc = hh.tail(400).copy() 
fc['type'] = 'original'

last_date = max(fc['tstp'])
hat_frame = pd.DataFrame({
    'tstp': [last_date + timedelta(hours=x + 1) for x in range(n_ahead)], 
    'energy(kWh/hh)': yhat,
    'type': 'forecast'
})

fc = fc.append(hat_frame)
fc.reset_index(inplace=True, drop=True)
#Ploting the forecasts 
plt.figure(figsize=(12, 8))
for col_type in ['original', 'forecast']:
    plt.plot(
        'tstp', 
        'energy(kWh/hh)', 
        data=fc[fc['type']==col_type],
        label=col_type
        )

plt.legend()
plt.grid()
# Out:
# /tmp/ipykernel_15415/2078647226.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fc = fc.append(hat_frame)

# %%
deep_learner.eval.MSE()
# Out:
# 0.0014211729273304959

# %%
deep_learner.eval.RMSE()
# Out:
# 0.037698447280100224

# %%
deep_learner.eval.MAE()
# Out:
# 0.01781039940929033

# %%
deep_learner.eval.MAPE()
# Out:
# 38.01209340670023

# %%
peaks, peak_dates, peak_indexes, res = deep_learner.eval.peak_daily_consumption()
pred = deep_learner.predict()
preds = [pred[x] for x in peak_indexes]
difference = [peaks[x] - preds[x] for x in range(len(peaks))]
res
# Out:
# 62.83094317774518

# %%
#preds

# %%
#peaks

# %%
#difference

# %%
# Constructing the forecast dataframe
fc = hh.tail(len(yhat)).copy()
fc.reset_index(inplace=True)
fc['forecast'] = yhat


hat_frame = pd.DataFrame({
    'tstp': peak_dates, 
    'energy(kWh/hh)': peaks,
    'forecast': preds, 
    
    'type': 'forecast'
})

# Ploting the forecasts
plt.figure(figsize=(12, 8))
for dtype in ['energy(kWh/hh)', 'forecast']:
  plt.plot(
    'tstp',
    dtype,
    data=hat_frame,
    label=dtype,
    alpha=0.8
  )
plt.title( "Energy Peaks")
plt.legend()
plt.grid()

# %%
plt.figure(figsize=(12, 8))
hat_frame = pd.DataFrame({
    'tstp': peak_dates, 
    'difference': difference,
    
    'type': 'forecast'
})

plt.plot(
    'tstp',
    'difference',
    data=hat_frame,
    label=dtype,
    alpha=0.8
  )

# %%
#train for all houses
lclid_list = df['LCLid'].unique().tolist()
#print(type(lclid_list))
mse = []
rmse = []
mae = []
mape = []
daily_peak_eval = []
for lclid in lclid_list:
    #print(lclid)


    hh = find_household(lclid)
    hh.pop("LCLid")
    #hh = hh.set_index("tstp")
    #hh = hh.resample("H").sum()
    #hh = hh.reset_index()

    hh_max = hh['energy(kWh/hh)'].max()
    hh['energy(kWh/hh)'] = hh['energy(kWh/hh)'].apply(lambda x: x / hh_max)
    
    # Initiating the class
    deep_learner = MLPModel(
        data = hh,
        Y_var = 'energy(kWh/hh)',
        lag = 24*2,
        layer_depths = [30],
        layer_count= 1,
        epochs = 20,
        batch_size = 256,
        train_test_split = 0.15
    )
    #training
    model = deep_learner.MLPModel()
    
    mse.append(deep_learner.eval.MSE())
    rmse.append(deep_learner.eval.RMSE())
    mae.append(deep_learner.eval.MAE())
    mape.append(deep_learner.eval.MAPE())
    _, _, _, res = deep_learner.eval.peak_daily_consumption()
    daily_peak_eval.append(res)
    
houses = pd.Series(data=lclid_list,name="lclid")
mse = pd.Series(data=mse,name="mse")
rmse = pd.Series(data=rmse,name="rmse")
mae = pd.Series(data=mae,name="mae")
mape = pd.Series(data=mape,name="mape")
dpe = pd.Series(data=daily_peak_eval,name="daily_peak_mape")


res_df = pd.merge(houses, mse, right_index=True, left_index=True)
res_df["rmse"] = rmse
res_df["mae"] = mae
res_df["mape"] = mape
res_df["daily_peak_mape"] =dpe
# Out:
# /tmp/ipykernel_15415/1120798320.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hh['energy(kWh/hh)'] = hh['energy(kWh/hh)'].apply(lambda x: x / hh_max)
# Epoch 1/20
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0067
# Epoch 2/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0055
# Epoch 3/20
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0052
# Epoch 4/20
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0050
# Epoch 5/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0049
# Epoch 6/20
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0049
# Epoch 7/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0049
# Epoch 8/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 9/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0048
# Epoch 10/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0048
# Epoch 11/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0048
# Epoch 12/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0048
# Epoch 13/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0048
# Epoch 14/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0048
# Epoch 15/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0048
# Epoch 16/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0048
# Epoch 17/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0048
# Epoch 18/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0048
# Epoch 19/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0047
# Epoch 20/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0047
# Epoch 1/20
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0069
# Epoch 2/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0054
# Epoch 3/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0045
# Epoch 4/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0042
# Epoch 5/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0041
# Epoch 6/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0040
# Epoch 7/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0040
# Epoch 8/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 9/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 10/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 11/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 12/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 13/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 14/20
# 132/132 [==============================] - 0s 984us/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 15/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 16/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 17/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 18/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 19/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 20/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 1/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0082 - val_loss: 0.0039
# Epoch 2/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0030
# Epoch 3/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 4/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 5/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 6/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 7/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 8/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 9/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 10/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 11/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 12/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 13/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 14/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 15/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 16/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 17/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 18/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 19/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 20/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 1/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 2/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 3/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 4/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 5/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 6/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 7/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 8/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 9/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 10/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 11/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 12/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 13/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 14/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 15/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 16/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 17/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 18/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 19/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 20/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 1/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0089 - val_loss: 0.0066
# Epoch 2/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0062 - val_loss: 0.0060
# Epoch 3/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0059 - val_loss: 0.0058
# Epoch 4/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 5/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 6/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 7/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 8/20
# 132/132 [==============================] - 0s 1000us/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 9/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 10/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0057
# Epoch 11/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 12/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 13/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 14/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 15/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 16/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 17/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 18/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 19/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 20/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 1/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0086 - val_loss: 0.0073
# Epoch 2/20
# 132/132 [==============================] - 0s 991us/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 3/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0064
# Epoch 4/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 5/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 6/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 7/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.0062
# Epoch 8/20
# 132/132 [==============================] - 0s 998us/step - loss: 0.0054 - val_loss: 0.0061
# Epoch 9/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.0061
# Epoch 10/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.0061
# Epoch 11/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.0061
# Epoch 12/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0061
# Epoch 13/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0060
# Epoch 14/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0060
# Epoch 15/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0060
# Epoch 16/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0060
# Epoch 17/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0060
# Epoch 18/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0060
# Epoch 19/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0060
# Epoch 20/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0060
# Epoch 1/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0081 - val_loss: 0.0094
# Epoch 2/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0072
# Epoch 3/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0065
# Epoch 4/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0062
# Epoch 5/20
# 132/132 [==============================] - 0s 995us/step - loss: 0.0032 - val_loss: 0.0060
# Epoch 6/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0059
# Epoch 7/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0059
# Epoch 8/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0031 - val_loss: 0.0059
# Epoch 9/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0058
# Epoch 10/20
# 132/132 [==============================] - 0s 985us/step - loss: 0.0030 - val_loss: 0.0058
# Epoch 11/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0058
# Epoch 12/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 13/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 14/20
# 132/132 [==============================] - 0s 998us/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 15/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 16/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 17/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 18/20
# 132/132 [==============================] - 0s 995us/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 19/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 20/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 1/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0202 - val_loss: 0.0079
# Epoch 2/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0077 - val_loss: 0.0064
# Epoch 3/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 4/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0056
# Epoch 5/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 6/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 7/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 8/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 9/20
# 132/132 [==============================] - 0s 991us/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 10/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 11/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0047
# Epoch 12/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 13/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 14/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 15/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0050 - val_loss: 0.0045
# Epoch 16/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 17/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 18/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 19/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 20/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 1/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0146 - val_loss: 0.0038
# Epoch 2/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0061 - val_loss: 0.0032
# Epoch 3/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0028
# Epoch 4/20
# 132/132 [==============================] - 0s 990us/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 5/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0025
# Epoch 6/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0024
# Epoch 7/20
# 132/132 [==============================] - 0s 994us/step - loss: 0.0038 - val_loss: 0.0023
# Epoch 8/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0023
# Epoch 9/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0023
# Epoch 10/20
# 132/132 [==============================] - 0s 997us/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 11/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 12/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 13/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 14/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 15/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 16/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 17/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 18/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 19/20
# 132/132 [==============================] - 0s 999us/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 20/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 1/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0069 - val_loss: 0.0054
# Epoch 2/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 3/20
# 132/132 [==============================] - 0s 993us/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 4/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 5/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 6/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 7/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 8/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 9/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 10/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 11/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 12/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 13/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 14/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 15/20
# 132/132 [==============================] - 0s 999us/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 16/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 17/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0045
# Epoch 18/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0045
# Epoch 19/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0045
# Epoch 20/20
# 132/132 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0045

# %%
res_df
# Out:
#        lclid       mse      rmse       mae        mape  daily_peak_mape
# 0  MAC000168  0.004745  0.068885  0.029658  109.255736        54.193150
# 1  MAC000169  0.003863  0.062154  0.031650   42.202642        45.326222
# 2  MAC000179  0.002664  0.051610  0.027169   42.241232        57.109068
# 3  MAC000181  0.001727  0.041551  0.018579   29.471314        55.066336
# 4  MAC000165  0.005598  0.074822  0.044875   25.893516        37.474200
# 5  MAC000173  0.005971  0.077269  0.045240   45.169757        57.281387
# 6  MAC000152  0.005701  0.075502  0.039716   74.789986        62.039473
# 7  MAC000153  0.004455  0.066748  0.044273   42.074509        22.848053
# 8  MAC000159  0.002096  0.045777  0.023476   28.040027        61.673489
# 9  MAC000150  0.004547  0.067435  0.038196   50.185345        58.438610
