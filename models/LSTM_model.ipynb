# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()


# Deep learning packages
from keras.models import Sequential
from keras.layers import LSTM, Dense

#enable IPython to display matplolib graphs
# %matplotlib inline
# Out:
# 2022-03-31 12:01:04.929176: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-31 12:01:04.929200: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
df = pd.read_csv('../data/ouput.csv')

# %%
df.head()
# Out:
#        LCLid                 tstp  energy(kWh/hh)
# 0  MAC000168  2011-11-24 13:30:00           0.054
# 1  MAC000168  2011-11-24 14:00:00           0.178
# 2  MAC000168  2011-11-24 14:30:00           0.113
# 3  MAC000168  2011-11-24 15:00:00           0.068
# 4  MAC000168  2011-11-24 15:30:00           0.061

# %%
df.shape
# Out:
# (396552, 3)

# %%
df['tstp'] = [datetime.strptime(x, '%Y-%m-%d %H:%M:%S') for x in df['tstp']]
df["tstp"] = pd.to_datetime(df["tstp"])
df["energy(kWh/hh)"] = pd.to_numeric(df["energy(kWh/hh)"], downcast="float", errors="coerce")

max_value_energy = df["energy(kWh/hh)"].max()
max_value_energy
# Out:
# 4.595

# %%
#max value for hh doesnt compare with hourly
#df['energy(kWh/hh)'] = df['energy(kWh/hh)'].apply(lambda x: x / max_value_energy)

# %%
# Sorting the values
#df.sort_values('tstp', inplace=True)

# %%
df.head()
# Out:
#        LCLid                tstp  energy(kWh/hh)
# 0  MAC000168 2011-11-24 13:30:00           0.054
# 1  MAC000168 2011-11-24 14:00:00           0.178
# 2  MAC000168 2011-11-24 14:30:00           0.113
# 3  MAC000168 2011-11-24 15:00:00           0.068
# 4  MAC000168 2011-11-24 15:30:00           0.061

# %%
df['energy(kWh/hh)'].max()
# Out:
# 4.595

# %%
df['energy(kWh/hh)'].min()
# Out:
# 0.0

# %%
from ML_classes.LSTMModel import LSTMModel

# %%
lclid_list = df['LCLid'].unique()
def find_household(identification):
    affluenthh_filt = df["LCLid"] == identification
    affluent_hh_data = df[affluenthh_filt]
    return affluent_hh_data

hh = find_household("MAC000150")
hh.pop("LCLid")
#hh = hh.set_index("tstp")
#hh = hh.resample("H").sum()
#hh = hh.reset_index()

hh_max = hh['energy(kWh/hh)'].max()
hh['energy(kWh/hh)'] = hh['energy(kWh/hh)'].apply(lambda x: x / hh_max)
# Out:
# /tmp/ipykernel_175457/194026773.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hh['energy(kWh/hh)'] = hh['energy(kWh/hh)'].apply(lambda x: x / hh_max)

# %%
#normalizedtstp = (hh["tstp"] - hh["tstp"].mean()) / hh["tstp"].std()
#normalizedtstp
type(hh.iloc[0]["energy(kWh/hh)"])
# Out:
# numpy.float64

# %%
# Initiating the class
deep_learner = LSTMModel(
data = hh,
Y_var = 'energy(kWh/hh)',
lag = 48,
LSTM_layer_depths = [50],
epochs =20,
batch_size = 256,
train_test_split = 0.15
)

# %%
# Fitting the model

model = deep_learner.LSTModel()
# Out:
# 2022-03-31 12:01:10.506609: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 12:01:10.506899: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-31 12:01:10.506947: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-03-31 12:01:10.506991: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-03-31 12:01:10.507034: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-03-31 12:01:10.507076: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-03-31 12:01:10.507118: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-03-31 12:01:10.507160: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-03-31 12:01:10.507202: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-03-31 12:01:10.507209: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-03-31 12:01:10.507379: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/20
# 132/132 [==============================] - 5s 33ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 2/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 3/20
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 4/20
# 132/132 [==============================] - 4s 29ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 5/20
# 132/132 [==============================] - 4s 29ms/step - loss: 0.0045 - val_loss: 0.0048
# Epoch 6/20
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 7/20
# 132/132 [==============================] - 4s 29ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 8/20
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 9/20
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 10/20
# 132/132 [==============================] - 4s 29ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 11/20
# 132/132 [==============================] - 4s 29ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 12/20
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 13/20
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 14/20
# 132/132 [==============================] - 4s 29ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 15/20
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 16/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 17/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 18/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 19/20
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 20/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0043 - val_loss: 0.0047

# %%
deep_learner.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                10400
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 10,451
# Trainable params: 10,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.ylim([0, 0.01])
    plt.xlabel('Epoch')
    plt.ylabel('Error [energy(kWh/hh)]')
    plt.legend()
    plt.grid(True)
plot_loss(deep_learner.history)

# %%
# Defining the lag that we used for training of the model 
lag_model = 48
# Getting the last period
ts = hh['energy(kWh/hh)'].tail(lag_model).values.tolist()
# Creating the X matrix for the model
X, _ = deep_learner.dc.create_X_Y(ts, lag=lag_model)
# Getting the forecast
yhat = model.predict(X)
yhat
# Out:
# array([[0.04260675]], dtype=float32)

# %%
yhat = deep_learner.predict()
# Constructing the forecast dataframe
fc = hh.tail(len(yhat)).copy()
fc.reset_index(inplace=True)
fc['forecast'] = yhat
# Ploting the forecasts
plt.figure(figsize=(12, 8))
for dtype in ['energy(kWh/hh)', 'forecast']:
  plt.plot(
    'tstp',
    dtype,
    data=fc,
    label=dtype,
    alpha=0.8
  )
plt.legend()
plt.grid()

# %%
# Forecasting n steps ahead
n_ahead = 168*2
yhat = deep_learner.predict_n_ahead(n_ahead)
yhat = [y[0][0] for y in yhat]

# Constructing the forecast dataframe
fc = hh.tail(400).copy() 
fc['type'] = 'original'

last_date = max(fc['tstp'])
hat_frame = pd.DataFrame({
    'tstp': [last_date + timedelta(hours=x + 1) for x in range(n_ahead)], 
    'energy(kWh/hh)': yhat,
    'type': 'forecast'
})

fc = fc.append(hat_frame)
fc.reset_index(inplace=True, drop=True)

# Ploting the forecasts 
plt.figure(figsize=(12, 8))
for col_type in ['original', 'forecast']:
    plt.plot(
        'tstp', 
        'energy(kWh/hh)', 
        data=fc[fc['type']==col_type],
        label=col_type
        )

plt.legend()
plt.grid()
# Out:
# /tmp/ipykernel_175457/370916521.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fc = fc.append(hat_frame)

# %%
#deep_learner.save_lstm_model()

# %%
deep_learner.eval.MSE()
# Out:
# 0.004673681097232681

# %%
deep_learner.eval.RMSE()
# Out:
# 0.06836432620331075

# %%
deep_learner.eval.MAE()
# Out:
# 0.03611703077192371

# %%
deep_learner.eval.MAPE()
# Out:
# 42.58851545602013

# %%
peaks, peak_dates, peak_indexes, res = deep_learner.eval.peak_daily_consumption()
pred = deep_learner.predict()
res
# Out:
# 63.00753172558979

# %%
# Constructing the forecast dataframe
fc = hh.tail(len(yhat)).copy()
fc.reset_index(inplace=True)
fc['forecast'] = yhat


hat_frame = pd.DataFrame({
    'tstp': peak_dates, 
    'energy(kWh/hh)': peaks,
    'forecast': [pred[x] for x in peak_indexes], 
    'type': 'forecast'
})

# Ploting the forecasts
plt.figure(figsize=(12, 8))
for dtype in ['energy(kWh/hh)', 'forecast']:
  plt.plot(
    'tstp',
    dtype,
    data=hat_frame,
    label=dtype,
    alpha=0.8
  )
plt.title( "Energy Peaks")
plt.legend()
plt.grid()

# %%
#train for all houses
lclid_list = df['LCLid'].unique().tolist()
#print(type(lclid_list))
mse = []
rmse = []
mae = []
mape = []
daily_peak_eval = []
for lclid in lclid_list:
    #print(lclid)


    hh = find_household(lclid)
    hh.pop("LCLid")
    #hh = hh.set_index("tstp")
    #hh = hh.resample("H").sum()
    #hh = hh.reset_index()

    hh_max = hh['energy(kWh/hh)'].max()
    hh['energy(kWh/hh)'] = hh['energy(kWh/hh)'].apply(lambda x: x / hh_max)
    
    # Initiating the class
    deep_learner = LSTMModel(
        data = hh,
        Y_var = 'energy(kWh/hh)',
        lag = 48,
        LSTM_layer_depths = [50],
        epochs =20,
        batch_size = 256,
        train_test_split = 0.15
    )
    #training
    model = deep_learner.LSTModel()
    
    mse.append(deep_learner.eval.MSE())
    rmse.append(deep_learner.eval.RMSE())
    mae.append(deep_learner.eval.MAE())
    mape.append(deep_learner.eval.MAPE())
    _, _, _, res = deep_learner.eval.peak_daily_consumption()
    daily_peak_eval.append(res)
houses = pd.Series(data=lclid_list,name="lclid")
mse = pd.Series(data=mse,name="mse")
rmse = pd.Series(data=rmse,name="rmse")
mae = pd.Series(data=mae,name="mae")
mape = pd.Series(data=mape,name="mape")
dpe = pd.Series(data=daily_peak_eval,name="daily_peak_mape")

res_df = pd.merge(houses, mse, right_index=True, left_index=True)
res_df["rmse"] = rmse
res_df["mae"] = mae
res_df["mape"] = mape
res_df["daily_peak_mape"] =dpe
# Out:
# /tmp/ipykernel_175457/237426048.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hh['energy(kWh/hh)'] = hh['energy(kWh/hh)'].apply(lambda x: x / hh_max)
# Epoch 1/20
# 132/132 [==============================] - 5s 33ms/step - loss: 0.0038 - val_loss: 0.0067
# Epoch 2/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0034 - val_loss: 0.0060
# Epoch 3/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0031 - val_loss: 0.0055
# Epoch 4/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0029 - val_loss: 0.0052
# Epoch 5/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0028 - val_loss: 0.0050
# Epoch 6/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0027 - val_loss: 0.0049
# Epoch 7/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0027 - val_loss: 0.0048
# Epoch 8/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0027 - val_loss: 0.0048
# Epoch 9/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 10/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 11/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 12/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 13/20
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 14/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 15/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 16/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 17/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 18/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 19/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0026 - val_loss: 0.0047
# Epoch 20/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0026 - val_loss: 0.0047
# Epoch 1/20
# 132/132 [==============================] - 6s 38ms/step - loss: 0.0051 - val_loss: 0.0058
# Epoch 2/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0034 - val_loss: 0.0050
# Epoch 3/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0030 - val_loss: 0.0044
# Epoch 4/20
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0028 - val_loss: 0.0043
# Epoch 5/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 6/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 7/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 8/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 9/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 10/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 11/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 12/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 13/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 14/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 15/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 16/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 17/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 18/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 19/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 20/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 1/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0063 - val_loss: 0.0038
# Epoch 2/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0047 - val_loss: 0.0034
# Epoch 3/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0042 - val_loss: 0.0032
# Epoch 4/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0040 - val_loss: 0.0031
# Epoch 5/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0038 - val_loss: 0.0030
# Epoch 6/20
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 7/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 8/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 9/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 10/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 11/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 12/20
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 13/20
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 14/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 15/20
# 132/132 [==============================] - 5s 42ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 16/20
# 132/132 [==============================] - 5s 40ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 17/20
# 132/132 [==============================] - 5s 41ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 18/20
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 19/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 20/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 1/20
# 132/132 [==============================] - 6s 41ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 2/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 3/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 4/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 5/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 6/20
# 132/132 [==============================] - 6s 43ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 7/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 8/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 9/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 10/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 11/20
# 132/132 [==============================] - 6s 49ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 12/20
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 13/20
# 132/132 [==============================] - 6s 44ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 14/20
# 132/132 [==============================] - 5s 41ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 15/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 16/20
# 132/132 [==============================] - 5s 41ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 17/20
# 132/132 [==============================] - 6s 42ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 18/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 19/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 20/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 1/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0108 - val_loss: 0.0082
# Epoch 2/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0075 - val_loss: 0.0079
# Epoch 3/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0071 - val_loss: 0.0074
# Epoch 4/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0068 - val_loss: 0.0068
# Epoch 5/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 6/20
# 132/132 [==============================] - 6s 46ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 7/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 8/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0059 - val_loss: 0.0061
# Epoch 9/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 10/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 11/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 12/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 13/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 14/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 15/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 16/20
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 17/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 18/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 19/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 20/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 1/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0085 - val_loss: 0.0094
# Epoch 2/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0066 - val_loss: 0.0074
# Epoch 3/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0061 - val_loss: 0.0071
# Epoch 4/20
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0059 - val_loss: 0.0069
# Epoch 5/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0059 - val_loss: 0.0068
# Epoch 6/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0058 - val_loss: 0.0067
# Epoch 7/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0058 - val_loss: 0.0067
# Epoch 8/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0057 - val_loss: 0.0067
# Epoch 9/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0057 - val_loss: 0.0066
# Epoch 10/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0057 - val_loss: 0.0066
# Epoch 11/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0057 - val_loss: 0.0066
# Epoch 12/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0057 - val_loss: 0.0065
# Epoch 13/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0056 - val_loss: 0.0065
# Epoch 14/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0056 - val_loss: 0.0065
# Epoch 15/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0056 - val_loss: 0.0064
# Epoch 16/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0056 - val_loss: 0.0065
# Epoch 17/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0056 - val_loss: 0.0065
# Epoch 18/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0056 - val_loss: 0.0064
# Epoch 19/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 20/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0055 - val_loss: 0.0065
# Epoch 1/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0051 - val_loss: 0.0077
# Epoch 2/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0040 - val_loss: 0.0069
# Epoch 3/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0036 - val_loss: 0.0065
# Epoch 4/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0034 - val_loss: 0.0062
# Epoch 5/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0033 - val_loss: 0.0060
# Epoch 6/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0033 - val_loss: 0.0059
# Epoch 7/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0032 - val_loss: 0.0059
# Epoch 8/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0032 - val_loss: 0.0058
# Epoch 9/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0031 - val_loss: 0.0058
# Epoch 10/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0031 - val_loss: 0.0057
# Epoch 11/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0031 - val_loss: 0.0057
# Epoch 12/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0031 - val_loss: 0.0057
# Epoch 13/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0031 - val_loss: 0.0057
# Epoch 14/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 15/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 16/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 17/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 18/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 19/20
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 20/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 1/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0154 - val_loss: 0.0105
# Epoch 2/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0113 - val_loss: 0.0106
# Epoch 3/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0100 - val_loss: 0.0088
# Epoch 4/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0088 - val_loss: 0.0081
# Epoch 5/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0082 - val_loss: 0.0071
# Epoch 6/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0079 - val_loss: 0.0071
# Epoch 7/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0079 - val_loss: 0.0071
# Epoch 8/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0078 - val_loss: 0.0071
# Epoch 9/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0078 - val_loss: 0.0070
# Epoch 10/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0077 - val_loss: 0.0070
# Epoch 11/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0077 - val_loss: 0.0070
# Epoch 12/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0077 - val_loss: 0.0070
# Epoch 13/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0077 - val_loss: 0.0070
# Epoch 14/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0077 - val_loss: 0.0070
# Epoch 15/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0077 - val_loss: 0.0070
# Epoch 16/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0076 - val_loss: 0.0070
# Epoch 17/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0076 - val_loss: 0.0070
# Epoch 18/20
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0076 - val_loss: 0.0070
# Epoch 19/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0075 - val_loss: 0.0067
# Epoch 20/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0080 - val_loss: 0.0071
# Epoch 1/20
# 132/132 [==============================] - 6s 35ms/step - loss: 0.0084 - val_loss: 0.0026
# Epoch 2/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0051 - val_loss: 0.0023
# Epoch 3/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0043 - val_loss: 0.0023
# Epoch 4/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0041 - val_loss: 0.0022
# Epoch 5/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0040 - val_loss: 0.0023
# Epoch 6/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0039 - val_loss: 0.0022
# Epoch 7/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 8/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 9/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 10/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 11/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 12/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 13/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 14/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 15/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 16/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 17/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 18/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 19/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 20/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 1/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0074 - val_loss: 0.0063
# Epoch 2/20
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 3/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 4/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 5/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 6/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 7/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 8/20
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 9/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 10/20
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 11/20
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 12/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 13/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 14/20
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 15/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 16/20
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 17/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 18/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 19/20
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 20/20
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0042 - val_loss: 0.0046

# %%
res_df
# Out:
#        lclid       mse      rmse       mae       mape  daily_peak_mape
# 0  MAC000168  0.004723  0.068727  0.024234  63.752849        55.028339
# 1  MAC000169  0.003809  0.061719  0.030180  36.560458        48.334526
# 2  MAC000179  0.002709  0.052048  0.028395  50.964698        57.461895
# 3  MAC000181  0.001717  0.041442  0.018536  30.318645        53.095492
# 4  MAC000165  0.005495  0.074130  0.042619  23.582932        39.403294
# 5  MAC000173  0.006462  0.080384  0.047318  44.835457        60.155993
# 6  MAC000152  0.005597  0.074814  0.039029  74.370031        59.281167
# 7  MAC000153  0.007071  0.084090  0.051225  42.770263        46.353663
# 8  MAC000159  0.002125  0.046101  0.022454  24.681519        62.586753
# 9  MAC000150  0.004568  0.067591  0.038313  51.560373        60.241866
